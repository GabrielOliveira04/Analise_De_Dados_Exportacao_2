# %%
import pandas as pd

tabela = pd.read_csv('exportacao_full.csv')
display(tabela)
# Out:
#           Year  Month      Country            City  SH4 Code  \
# 0         2010      1  Afghanistan     Itajaí - SC       207
# 1         2010      1  Afghanistan       Lapa - PR       207
# 2         2010      1  Afghanistan   Rolândia - PR       207
# 3         2010      1  Afghanistan  São Paulo - SP       207
# 4         2010      1  Afghanistan      Xaxim - SC       207
# ...        ...    ...          ...             ...       ...
# 13124808  2013     10      Nigeria    Barueri - SP      8414
# 13124809  2013     10      Nigeria    Barueri - SP      8421
# 13124810  2013     10      Nigeria    Barueri - SP      8482
# 13124811  2013     10      Nigeria    Barueri - SP      8512
# 13124812  2013     10      Nigeria    Barueri - SP      8708
#
#                                             SH4 Description  SH2 Code  \
# 0         Meat and edible offal, of the poultry of headi...         2
# 1         Meat and edible offal, of the poultry of headi...         2
# ...

# %%
tabela = tabela.loc[tabela['Year']>=2014,:]
tabela = tabela.loc[tabela['Country']=='Afghanistan', :]
display(tabela)
# Out:
#           Year  Month      Country             City  SH4 Code  \
# 309928    2014      1  Afghanistan     Cubatão - SP       207
# 309929    2014      1  Afghanistan      Itajaí - SC       207
# 309930    2014      1  Afghanistan  Montenegro - RS       207
# 309931    2014      1  Afghanistan   Paranaguá - PR       207
# 309932    2014      1  Afghanistan  Rio Grande - RS       207
# ...        ...    ...          ...              ...       ...
# 12927607  2020     12  Afghanistan     Pompéia - SP      7318
# 12927608  2020     12  Afghanistan     Pompéia - SP      7326
# 12927609  2020     12  Afghanistan     Pompéia - SP      8421
# 12927610  2020     12  Afghanistan     Pompéia - SP      8424
# 12927611  2020     12  Afghanistan     Pompéia - SP      8481
#
#                                             SH4 Description  SH2 Code  \
# 309928    Meat and edible offal, of the poultry of headi...         2
# 309929    Meat and edible offal, of the poultry of headi...         2
# ...

# %%
tabela.to_csv("exportacao_Afghanistan.csv", index=False)
